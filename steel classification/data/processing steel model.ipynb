# %%
# necessary libraires
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
# loading the data
df = pd.read_csv('/content/faults.csv')

# %%
df.head()
# Out:
#    X_Minimum  X_Maximum  Y_Minimum  Y_Maximum  Pixels_Areas  X_Perimeter  \
# 0         42         50     270900     270944           267           17
# 1        645        651    2538079    2538108           108           10
# 2        829        835    1553913    1553931            71            8
# 3        853        860     369370     369415           176           13
# 4       1289       1306     498078     498335          2409           60
#
#    Y_Perimeter  Sum_of_Luminosity  Minimum_of_Luminosity  \
# 0           44              24220                     76
# 1           30              11397                     84
# 2           19               7972                     99
# 3           45              18996                     99
# 4          260             246930                     37
#
#    Maximum_of_Luminosity  ...  Orientation_Index  Luminosity_Index  \
# 0                    108  ...             0.8182           -0.2913
# ...

# %%
df.isnull().sum()
# Out:
# X_Minimum                0
# X_Maximum                0
# Y_Minimum                0
# Y_Maximum                0
# Pixels_Areas             0
# X_Perimeter              0
# Y_Perimeter              0
# Sum_of_Luminosity        0
# Minimum_of_Luminosity    0
# Maximum_of_Luminosity    0
# Length_of_Conveyer       0
# TypeOfSteel_A300         0
# TypeOfSteel_A400         0
# Steel_Plate_Thickness    0
# Edges_Index              0
# Empty_Index              0
# Square_Index             0
# Outside_X_Index          0
# Edges_X_Index            0
# Edges_Y_Index            0
# Outside_Global_Index     0
# LogOfAreas               0
# Log_X_Index              0
# Log_Y_Index              0
# Orientation_Index        0
# Luminosity_Index         0
# SigmoidOfAreas           0
# Pastry                   0
# Z_Scratch                0
# K_Scatch                 0
# Stains                   0
# Dirtiness                0
# Bumps                    0
# Other_Faults             0
# ...

# %%
df.describe()
# Out:
#          X_Minimum    X_Maximum     Y_Minimum     Y_Maximum   Pixels_Areas  \
# count  1941.000000  1941.000000  1.941000e+03  1.941000e+03    1941.000000
# mean    571.136012   617.964451  1.650685e+06  1.650739e+06    1893.878413
# std     520.690671   497.627410  1.774578e+06  1.774590e+06    5168.459560
# min       0.000000     4.000000  6.712000e+03  6.724000e+03       2.000000
# 25%      51.000000   192.000000  4.712530e+05  4.712810e+05      84.000000
# 50%     435.000000   467.000000  1.204128e+06  1.204136e+06     174.000000
# 75%    1053.000000  1072.000000  2.183073e+06  2.183084e+06     822.000000
# max    1705.000000  1713.000000  1.298766e+07  1.298769e+07  152655.000000
#
#         X_Perimeter   Y_Perimeter  Sum_of_Luminosity  Minimum_of_Luminosity  \
# count   1941.000000   1941.000000       1.941000e+03            1941.000000
# mean     111.855229     82.965997       2.063121e+05              84.548686
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1941 entries, 0 to 1940
# Data columns (total 34 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   X_Minimum              1941 non-null   int64
#  1   X_Maximum              1941 non-null   int64
#  2   Y_Minimum              1941 non-null   int64
#  3   Y_Maximum              1941 non-null   int64
#  4   Pixels_Areas           1941 non-null   int64
#  5   X_Perimeter            1941 non-null   int64
#  6   Y_Perimeter            1941 non-null   int64
#  7   Sum_of_Luminosity      1941 non-null   int64
#  8   Minimum_of_Luminosity  1941 non-null   int64
#  9   Maximum_of_Luminosity  1941 non-null   int64
#  10  Length_of_Conveyer     1941 non-null   int64
#  11  TypeOfSteel_A300       1941 non-null   int64
#  12  TypeOfSteel_A400       1941 non-null   int64
#  13  Steel_Plate_Thickness  1941 non-null   int64
#  14  Edges_Index            1941 non-null   float64
# ...

# %%
df.shape
# Out:
# (1941, 34)

# %%
df.columns
# Out:
# Index(['X_Minimum', 'X_Maximum', 'Y_Minimum', 'Y_Maximum', 'Pixels_Areas',
#        'X_Perimeter', 'Y_Perimeter', 'Sum_of_Luminosity',
#        'Minimum_of_Luminosity', 'Maximum_of_Luminosity', 'Length_of_Conveyer',
#        'TypeOfSteel_A300', 'TypeOfSteel_A400', 'Steel_Plate_Thickness',
#        'Edges_Index', 'Empty_Index', 'Square_Index', 'Outside_X_Index',
#        'Edges_X_Index', 'Edges_Y_Index', 'Outside_Global_Index', 'LogOfAreas',
#        'Log_X_Index', 'Log_Y_Index', 'Orientation_Index', 'Luminosity_Index',
#        'SigmoidOfAreas', 'Pastry', 'Z_Scratch', 'K_Scatch', 'Stains',
#        'Dirtiness', 'Bumps', 'Other_Faults'],
#       dtype='object')

# %%
df.columns = df.columns.str.lower().str.strip()

# %%
fault_columns = ['pastry', 'z_scratch', 'k_scatch', 'stains', 'dirtiness', 'bumps', 'other_faults']

def merge_fault_columns(row):
    for col in fault_columns:
        if row[col] == 1:
            return col
    return 'no_fault'

df['target_col'] = df.apply(merge_fault_columns, axis=1)

# %%
df['target_col'].value_counts()
# Out:
# target_col
# other_faults    673
# bumps           402
# k_scatch        391
# z_scratch       190
# pastry          158
# stains           72
# dirtiness        55
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
import pickle as pkl
import os

# %%
def engineer_data(df):
   '''
   this function engineer the data and create new features for better genralisation
   '''

   df['fault_width'] = df['x_maximum'] - df['x_minimum']
   df['fault_length'] = df['y_maximum'] - df['y_minimum']
   df['fault_area_estimate'] = df['fault_width'] * df['fault_length']
   df['thickness'] = df['steel_plate_thickness'] / (df['pixels_areas'] + 1e-5)

   return df

# %%
def pipeline(df ,target_col='target_col',save_dir='model'):
   '''
   this function engineer the data and create new features for better genralisation
   '''
   # Create the save directory if it doesn't exist
   os.makedirs(save_dir, exist_ok=True)

   df = engineer_data(df)
   X = df.drop(columns=[target_col])
   y = df[target_col]

   #the 7 multi-class categorical targets into integers (0 to 6)
   label_encoder = LabelEncoder()
   y_encoded = label_encoder.fit_transform(y)
   pkl.dump(label_encoder, os.path.join(save_dir, 'label_encoder.pkl'))

   #Split into train and validation sets
   X_train, X_val, y_train, y_val = train_test_split(X, y_encoded, test_size=0.2, random_state=42, stratify=y_encoded)

   # Scale features (essential for Stacking Meta-models like Logistic Regression)
   scaler = StandardScaler()
   X_train_scaled = scaler.fit_transform(X_train)
   X_val_scaled = scaler.transform(X_val)
   pkl.dump(scaler, os.path.join(save_dir, 'scaler.pkl'))

   # Convert back to dataframes keeping track of engineered feature names
   feature_names = X.columns
   X_train_scaled = pd.DataFrame(X_train_scaled, columns=feature_names)
   X_val_scaled = pd.DataFrame(X_val_scaled, columns=feature_names)

   print(" Preprocessing complete. Scaler and Label Encoder saved.")
   return X_train_scaled, X_val_scaled, y_train, y_val

# %%
from sklearn.ensemble import RandomForestClassifier, StackingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score
from xgboost import XGBClassifier
import pickle as pkl

def train_ensemble_pipeline(data):
    # Get preprocessed data from our module
    X_train, X_val, y_train, y_val = pipeline(data)

    print("\nInitializing Base Models for the Ensemble...")

    # 1. Base Model 1: Random Forest (Bagging)
    rf_base = RandomForestClassifier(
        n_estimators=200,
        max_depth=10,
        random_state=42,
        n_jobs=-1
    )

    # 2. Base Model 2: XGBoost (Boosting)
    xgb_base = XGBClassifier(
        n_estimators=200,
        learning_rate=0.05,
        max_depth=6,
        eval_metric='mlogloss',
        random_state=42,
        n_jobs=-1
    )

    # 3. The Meta-Learner (Stacking)
    # Stacking uses cross-validation predictions of base models to train the final estimator
    base_learners = [
        ('random_forest', rf_base),
        ('xgboost', xgb_base)
    ]

    meta_learner = LogisticRegression(max_iter=500)

    stacking_model = StackingClassifier(
        estimators=base_learners,
        final_estimator=meta_learner,
        cv=5, # 5-fold cross-validation for meta-training
        n_jobs=-1
    )

    # Train the end-to-end ensemble
    print("Training the Stacking Ensemble (this takes care of internal CV)...")
    stacking_model.fit(X_train, y_train)

    # Evaluate the model
    y_pred = stacking_model.predict(X_val)

    # Load label encoder to print actual class names instead of numbers (0-6)
    le = pkl.load('label_encoder.pkl')
    target_names = le.classes_

    print("\n=== ENSEMBLE PERFORMANCE ===")
    print(f"Validation Accuracy: {accuracy_score(y_val, y_pred):.4f}")
    print("\nClassification Report:")
    print(classification_report(y_val, y_pred, target_names=target_names))

    # Save the final ensemble model
    model_output_path = 'steel_faults_ensemble.pkl'
    pkl.dump(stacking_model, model_output_path)
    print(f"Final Stacking Ensemble model saved successfully to: {model_output_path}")

# %%
os.makedirs('model', exist_ok=True)
train_ensemble_pipeline(df)
# Out:
#  Preprocessing complete. Scaler and Label Encoder saved.
#
# Initializing Base Models for the Ensemble...
# Training the Stacking Ensemble (this takes care of internal CV)...
#
# === ENSEMBLE PERFORMANCE ===
# Validation Accuracy: 1.0000
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        bumps       1.00      1.00      1.00        81
#    dirtiness       1.00      1.00      1.00        11
#     k_scatch       1.00      1.00      1.00        78
# other_faults       1.00      1.00      1.00       135
#       pastry       1.00      1.00      1.00        32
#       stains       1.00      1.00      1.00        14
#    z_scratch       1.00      1.00      1.00        38
#
#     accuracy                           1.00       389
#    macro avg       1.00      1.00      1.00       389
# weighted avg       1.00      1.00      1.00       389
#
# Final Stacking Ensemble model saved successfully to: steel_faults_ensemble.pkl
